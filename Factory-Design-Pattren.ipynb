# %%
from abc import ABCMeta, abstractstaticmethod

class IPerson(metaclass=ABCMeta):
    @abstractstaticmethod
    def person_method():
        """ Interface Method """
        pass


class Student(IPerson):
    def __init__(self):
        self.name = "Basic Student Name"

    def person_method(self):
        print("I am a student")


class Teacher(IPerson):
    def __init__(self):
        self.name = "Basic Teacher Name"

    def person_method(self):
        print("I am a teacher")


# Example usage
s1 = Student()
s1.person_method()

t1 = Teacher()
t1.person_method()
# Out:
# I am a student
# I am a teacher

# %%
from abc import ABCMeta, abstractstaticmethod

class IPerson(metaclass=ABCMeta):
    @abstractstaticmethod
    def person_method():
        """ Interface Method """
        pass


class Student(IPerson):
    def __init__(self):
        self.name = "Basic Student Name"

    def person_method(self):
        print("I am a student")


class Teacher(IPerson):
    def __init__(self):
        self.name = "Basic Teacher Name"

    def person_method(self):
        print("I am a teacher")


class PersonFactory:
    @staticmethod
    def build_person(person_type):
        if person_type == "Student":
            return Student()
        if person_type == "Teacher":
            return Teacher()
        print("Invalid Type")
        return None


# Example usage
choice = input("What type of person do you want to create? (Student/Teacher): ")
person = PersonFactory.build_person(choice)
person.person_method()
# Out:
# I am a student

# %%
#proxy design pattern

# %%
from abc import ABCMeta, abstractstaticmethod

class IPerson(metaclass=ABCMeta):

    @abstractstaticmethod
    def person_method():
        """ Interface Method """


class Person(IPerson):

    def person_method(self):
        print("I am a person!")


class ProxyPerson(IPerson):

    def __init__(self):
        self.person = Person()

    def person_method(self):
        print("I am the proxy functionality!")
        self.person.person_method()


p1 = Person()
p1.person_method()

p2 = ProxyPerson()
p2.person_method()
# Out:
# I am a person!
# I am the proxy functionality!
# I am a person!

# %%
#singleton design pattern

# %%
from abc import ABCMeta, abstractstaticmethod

class IPerson(metaclass=ABCMeta):

    @abstractstaticmethod
    def print_data():
        """ implement in child class """


class PersonSingleton(IPerson):

    __instance = None

    @staticmethod
    def get_instance():
        if PersonSingleton.__instance is None:
            PersonSingleton("Default Name", 0)
        return PersonSingleton.__instance

    def __init__(self, name, age):
        if PersonSingleton.__instance is not None:
            raise Exception("Singleton cannot be instantiated more than once!")
        else:
            self.name = name
            self.age = age
            PersonSingleton.__instance = self

    @staticmethod
    def print_data():
        print(f"Name: {PersonSingleton.__instance.name}, Age: {PersonSingleton.__instance.age}")

P=PersonSingleton("John Doe", 30)
print(P)
P.print_data()
# Out:
# <__main__.PersonSingleton object at 0x0000020256BE5E70>
# Name: John Doe, Age: 30

# %%
P1=PersonSingleton("John Doe", 30)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 P1=PersonSingleton("John Doe", 30)
#
# Cell In[2], line 22, in PersonSingleton.__init__(self, name, age)
#      20 def __init__(self, name, age):
#      21     if PersonSingleton.__instance is not None:
# ---> 22         raise Exception("Singleton cannot be instantiated more than once!")
#      23     else:
#      24         self.name = name
#
# Exception: Singleton cannot be instantiated more than once!

# %%
P2=PersonSingleton.get_instance()
print(P2)
P2.print_data()
# Out:
# <__main__.PersonSingleton object at 0x0000020256BE5E70>
# Name: John Doe, Age: 30

# %%
#composite design pattern

# %%
from abc import ABCMeta, abstractmethod, abstractstaticmethod

class IDepartment(metaclass=ABCMeta):

    @abstractmethod
    def __init__(self, employees):
        """ implement in child class """

    @abstractstaticmethod
    def print_department():
        """ implement in child class """


class Accounting(IDepartment):

    def __init__(self, employees):
        self.employees = employees

    def print_department(self):
        print(f"Accounting Department: {self.employees}")


class Development(IDepartment):

    def __init__(self, employees):
        self.employees = employees

    def print_department(self):
        print(f"Development Department: {self.employees}")


class ParentDepartment(IDepartment):

    def __init__(self, employees):
        self.employees = employees
        self.base_employees = employees
        self.sub_depts = []

    def add(self, dept):
        self.sub_depts.append(dept)
        self.employees += dept.employees

    def print_department(self):
        print("Parent Department")
        print(f"Parent Department Base Employees: {self.base_employees}")
        for dept in self.sub_depts:
            dept.print_department()
        print(f"Total number of employees: {self.employees}")


# Example usage
dept1 = Accounting(200)
dept2 = Development(170)

parent_dept = ParentDepartment(30)
parent_dept.add(dept1)
parent_dept.add(dept2)

parent_dept.print_department()
# Out:
# Parent Department
# Parent Department Base Employees: 30
# Accounting Department: 200
# Development Department: 170
# Total number of employees: 400

# %%
#type hinting example

# %%
def myfunction(myparameter: int) -> str:
    return f"{myparameter + 10}"


def otherfunction(otherparameter: str):
    print(otherparameter)


otherfunction(myfunction(20))
# Out:
# 30

# %%
def doSth(param: list[int]):
    print(param)
